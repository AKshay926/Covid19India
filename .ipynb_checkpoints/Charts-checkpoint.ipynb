# %%
#importing the libraries
import plotly.express as px
from plotly.offline import plot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import pycountry_convert as pc
from datetime import datetime
import folium
import branca
from datetime import datetime, timedelta,date
from scipy.interpolate import make_interp_spline, BSpline
import json, requests
import calmap
from matplotlib import pyplot as plt
import pandas as pd
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
#reading the data into a pandas dataframe
df = pd.read_csv('COVID19INDIA.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Get last date to see which states have the most cases currently
last_date = df['Date'].max()
states_data = df[ df['Date'] == last_date]
states_data = states_data.drop(['Latitude', 'Longitude', 'Date'], axis=1)
states_data.index = states_data['States']
states_data = states_data.drop(['States'], axis=1)
states_data.sort_values('Total Cases', ascending= False).style.background_gradient(cmap='BuPu')
# Out:
# <style  type="text/css" >
#     #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow0_col0 {
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow0_col1 {
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow0_col2 {
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow0_col3 {
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow1_col0 {
#             background-color:  #e9f2f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow1_col1 {
#             background-color:  #95aad0;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow1_col2 {
#             background-color:  #a9c4de;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow1_col3 {
#             background-color:  #bacfe4;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow2_col0 {
#             background-color:  #c7d9e9;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow2_col1 {
#             background-color:  #b4cce2;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow2_col2 {
#             background-color:  #b2cae1;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow2_col3 {
#             background-color:  #b0c9e1;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow3_col0 {
#             background-color:  #93a5ce;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow3_col1 {
#             background-color:  #a3bfdc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow3_col2 {
#             background-color:  #c1d4e7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow3_col3 {
#             background-color:  #dce9f2;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow4_col0 {
#             background-color:  #e8f1f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow4_col1 {
#             background-color:  #ccddec;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow4_col2 {
#             background-color:  #e0ecf4;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow4_col3 {
#             background-color:  #eaf3f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow5_col0 {
#             background-color:  #dae7f1;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow5_col1 {
#             background-color:  #d6e4f0;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow5_col2 {
#             background-color:  #e1edf5;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow5_col3 {
#             background-color:  #e9f2f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow6_col0 {
#             background-color:  #e6f0f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow6_col1 {
#             background-color:  #d7e5f0;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow6_col2 {
#             background-color:  #e2edf5;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow6_col3 {
#             background-color:  #e9f2f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow7_col0 {
#             background-color:  #ddeaf3;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow7_col1 {
#             background-color:  #e9f2f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow7_col2 {
#             background-color:  #e8f1f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow7_col3 {
#             background-color:  #e8f1f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow8_col0 {
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow8_col1 {
#             background-color:  #ebf4f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow8_col2 {
#             background-color:  #edf5f9;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow8_col3 {
#             background-color:  #eef5f9;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow9_col0 {
#             background-color:  #f3f9fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow9_col1 {
#             background-color:  #e9f2f7;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow9_col2 {
#             background-color:  #eef5f9;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow9_col3 {
#             background-color:  #f1f7fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow10_col0 {
#             background-color:  #f3f9fc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow10_col1 {
#             background-color:  #eff6fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow10_col2 {
#             background-color:  #eef6fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow10_col3 {
#             background-color:  #eef5f9;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow11_col0 {
#             background-color:  #f1f7fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow11_col1 {
#             background-color:  #eef6fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow11_col2 {
#             background-color:  #f0f7fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow11_col3 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow12_col0 {
#             background-color:  #f5fafc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow12_col1 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow12_col2 {
#             background-color:  #f1f7fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow12_col3 {
#             background-color:  #eff6fa;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow13_col0 {
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow13_col1 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow13_col2 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow13_col3 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow14_col0 {
#             background-color:  #f4fafc;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow14_col1 {
#             background-color:  #ebf3f8;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow14_col2 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0f66e62a_a4f7_11ea_996d_2cf0ee25c1aerow14_col3 {
#             background-color:  #f6fbfd;

# %%
# Get latest data to see heatmap
last_date = df['Date'].max()
latest_df = df[ df['Date'] == last_date]
latest_df.columns


latest_df = latest_df.fillna(0)

# %%
#generating a world map

world_map = folium.Map(location=[20,78], tiles="cartodbpositron", zoom_start=4,max_zoom=7,min_zoom=4)
    
for i in range(0,len(latest_df)):
    folium.Circle(
        location=[latest_df.iloc[i]['Latitude'], latest_df.iloc[i]['Longitude']],
        tooltip = "<h3 style='text-align:center;font-weight: bold'>"+latest_df.iloc[i]['States']+"</h3>"
        "<hr style='margin:10px;'>"
        "<ul style='color: #444; list-style-type:circle; align-item:left; padding-left:20px; padding-right:20px'>"
        "<li>Confirmed: "+str(latest_df.iloc[i,1])+"</li>"
        "<li>Deaths:   "+str(latest_df.iloc[i,3])+"</li>"
        "<li>Active:   "+str(latest_df.iloc[i,-1])+"</li>"
        "</ul>",
        radius = (int((np.log(latest_df.iloc[i,3]+1.00001)))+0.2)*50000,
        color='navy',
        fill_color='darkblue',
    fill=True).add_to(world_map)
 
world_map

#world_map.save('india_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Calendar View
#
# **Note**:The data was we scrapped on  21/04/2020, hence the historicals prior to this date will be missing in the representation.

# %%
calmap_data = df.copy().drop(['States','Latitude', 'Longitude'], axis=1)
calmap_data = calmap_data.groupby(['Date']).sum().diff()

# %%
f = plt.figure(figsize=(20,10))
#f.add_subplot(2,1,1)
cax = calmap.yearplot(calmap_data['Total Cases'], fillcolor='white', cmap='Blues', linewidth=0.5,linecolor="#fafafa",year=2020)
plt.title("Daily Confirmed Cases",fontsize=20)
plt.tick_params(labelsize=15)
plt.colorbar(cax.get_children()[1], ax=cax, orientation='horizontal')
plt.show()
# Save the output as a PNG image
f.savefig("Daily_Confirmed_Case_CalenderView.png", dpi=100)

# %%
f = plt.figure(figsize=(20,10))
#f.add_subplot(2,1,2)
cax = calmap.yearplot(calmap_data['Death'], fillcolor='white', cmap='Greens', linewidth=1,linecolor="#fafafa",year=2020)
plt.title("Daily Death Cases",fontsize=20)
plt.tick_params(labelsize=15)
plt.colorbar(cax.get_children()[1], orientation='horizontal')
plt.show()
f.savefig("Daily_Deaths_CalenderView.png", dpi=100)

# %%
f = plt.figure(figsize=(18,9))
f.add_subplot(111)

unique_states = df['States'].unique()

# Get last date to see which Countrys have the most cases currently
last_date = df['Date'].max()
df_last_date = df[ df['Date'] == last_date]
series_last_date = df_last_date.groupby('States')['Total Cases'].sum()
series_last_date = series_last_date.nlargest(10)

#print(series_last_date)
# start date
date_after = df['Date'].min()
#print(date_after)

for states in series_last_date.index:
    df_states = df[ df['States'] == states].copy()
    df_states['Date'] = pd.to_datetime(df_states['Date'])
    df_states = df_states[ df_states['Date'] >= date_after]

    series_states = df_states.groupby('Date')['Total Cases'].sum()
    series_states = series_states.diff()
    series_states.index = series_states.index.strftime('%b %d')
    plt.plot(series_states.index, series_states.values, label=states)

plt.ylabel("No. of cases")
plt.title('Covid-19 in India ')
plt.grid(True)

# rotate dates.
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
f.savefig("Daily_Case_Line_Chart.png", dpi=100)

# %%
unique_states = df['States'].unique()
plt.style.use("seaborn-talk")


# Get last date to see which states have the most cases currently
last_date = df['Date'].max()
df_last_date = df[df['Date'] == last_date]
series_last_date = df_last_date.groupby('States')['Total Cases'].sum().sort_values(ascending=False)
#print(series_last_date)

labels = []
values = []
state_count = 5
other_total = 0
for state in series_last_date.index:
    if state_count > 0:
        labels.append(state)
        values.append(series_last_date[state])
        state_count -= 1
    else:
        other_total += series_last_date[state]
labels.append("Other")
values.append(other_total)

wedge_dict = {
    'edgecolor': 'black',
    'linewidth': 2        
}

explode = (0, 0.1, 0, 0, 0, 0)

plt.title("Total Cases")
plt.pie(values, labels=labels, explode=explode, autopct='%1.1f%%', wedgeprops=wedge_dict)
plt.show()
f.savefig("Percentage of total cases.png", dpi=100)
