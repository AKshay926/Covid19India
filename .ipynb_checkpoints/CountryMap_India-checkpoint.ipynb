# %%
# required imports

import xlrd
import random
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('COVID19INDIA.csv')
df.head()
# Out:
#                         States  Total Cases  Recovered  Death        Date  \
# 0  Andaman and Nicobar Islands         16.0       11.0    0.0  2020-04-21
# 1               Andhra Pradesh        757.0       96.0   22.0  2020-04-21
# 2            Arunachal Pradesh          1.0        1.0    0.0  2020-04-21
# 3                        Assam         35.0       19.0    1.0  2020-04-21
# 4                        Bihar        114.0       42.0    2.0  2020-04-21
#
#    Latitude  Longitude  Active
# 0   11.7401    92.6586     5.0
# 1   15.9129    79.7400   639.0
# 2   28.2180    94.7278     0.0
# 3   26.2006    92.9376    15.0
# 4   25.0961    85.3131    70.0

# %%
fp = "Igismap/Indian_States.shp"
map_df = gpd.read_file(fp)
map_df
# Out:
#                        st_nm  \
# 0   Andaman & Nicobar Island
# 1         Arunanchal Pradesh
# 2                      Assam
# 3                      Bihar
# 4                 Chandigarh
# 5               Chhattisgarh
# 6     Dadara & Nagar Havelli
# 7                Daman & Diu
# 8                        Goa
# 9                    Gujarat
# 10                   Haryana
# 11          Himachal Pradesh
# 12           Jammu & Kashmir
# 13                 Jharkhand
# 14                 Karnataka
# 15                    Kerala
# 16               Lakshadweep
# 17            Madhya Pradesh
# 18               Maharashtra
# 19                   Manipur
# 20                 Meghalaya
# 21                   Mizoram
# 22                  Nagaland
# 23              NCT of Delhi
# 24                Puducherry
# 25                    Punjab
# 26                 Rajasthan
# 27                    Sikkim
# 28                Tamil Nadu
# 29                 Telangana
# 30                   Tripura
# 31             Uttar Pradesh
# 32               Uttarakhand
# 33               West Bengal
# 34                    Odisha
# 35            Andhra Pradesh
#
#                                              geometry
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# 6   POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# 7   MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# 10  POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# 11  POLYGON ((76.79634 33.25490, 76.80351 33.25275...
# 12  POLYGON ((74.73451 37.02068, 74.73647 37.01937...
# 13  POLYGON ((87.60582 25.31512, 87.61279 25.31184...
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...
# 15  POLYGON ((74.99575 12.79227, 75.00006 12.78777...
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...
# 19  POLYGON ((94.57602 25.64221, 94.57487 25.63858...
# 20  POLYGON ((91.85632 26.10353, 91.86717 26.09906...
# 21  POLYGON ((92.80022 24.41630, 92.80310 24.41603...
# 22  POLYGON ((95.21458 26.93095, 95.21719 26.92818...
# 23  POLYGON ((77.09361 28.86940, 77.10973 28.86722...
# 24  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...
# 25  POLYGON ((75.88469 32.48841, 75.90303 32.47169...
# 26  POLYGON ((73.89849 29.97896, 73.90021 29.97140...
# 27  POLYGON ((88.65381 28.09883, 88.66265 28.08956...
# 28  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...
# 29  POLYGON ((81.05614 17.79097, 81.05834 17.75464...
# 30  POLYGON ((92.22108 24.50131, 92.22771 24.49862...
# 31  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...
# 32  POLYGON ((79.21047 31.34846, 79.21386 31.34680...
# 33  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 34  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...
# 35  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...

# %%
# change state name to match in both files -- I manually checked few
map_df['st_nm'].iloc[0]  = 'Andaman and Nicobar Islands'
map_df['st_nm'].iloc[12] = 'Jammu and Kashmir'
map_df['st_nm'].iloc[6] = 'Dadara and Nagar Havelli'
map_df['st_nm'].iloc[23] = 'Delhi'
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#default plot
map_df.plot()

# %%
# Join both the DataFrames by state names

merged = map_df.set_index('st_nm').join(df.set_index('States'))

#fill NaN values with Zero

merged[['Total Cases', 'Recovered', 'Death']] = merged[['Total Cases', 'Recovered', 'Death']].fillna(0).astype('int')
merged.head()
# Out:
#                                                                       geometry  \
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Andaman and Nicobar Islands  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Andhra Pradesh               MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
#
#                              Total Cases  Recovered  Death        Date  \
# Andaman and Nicobar Islands           16         11      0  2020-04-21
# Andaman and Nicobar Islands           16         11      0  2020-04-22
# Andaman and Nicobar Islands           18         11      0  2020-04-23
# Andaman and Nicobar Islands           22         11      0  2020-04-24
# Andhra Pradesh                       757         96     22  2020-04-21
#
#                              Latitude  Longitude  Active
# Andaman and Nicobar Islands   11.7401    92.6586     5.0
# Andaman and Nicobar Islands   11.7401    92.6586     5.0
# Andaman and Nicobar Islands   11.7401    92.6586     7.0
# Andaman and Nicobar Islands   11.7401    92.6586    11.0
# Andhra Pradesh                15.9129    79.7400   639.0

# %%
# create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(23, 19))
ax.axis('on')
ax.set_title('Total COVID-19 cases in India', fontdict={'fontsize': '35', 'fontweight' : '5'})

# plot the figure
merged.plot(column='Total Cases', cmap='RdBu', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
# Save the output as a PNG image
fig.savefig("TotalCase_India.png", dpi=100)

# %%
# create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(23, 19))
ax.axis('on')
ax.set_title('Total Deaths due to COVID-19 in India', fontdict={'fontsize': '35', 'fontweight' : '5'})

# plot the figure
merged.plot(column='Death', cmap='RdBu', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# %%
# Save the output as a PNG image
fig.savefig("TotalDeath_India.png", dpi=100)
